# %% [markdown]
# ## Model Fitting and Evaluation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV, ElasticNetCV

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
train = pd.read_csv('../datasets/eda_feature_engineered.csv')
test = pd.read_csv('../datasets/test_cleaned.csv')

# %%
train.head()
# Out:
#    MS SubClass  MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 0           60          1          74.0     13517   Pave    Na       IR1
# 1           60          1          43.0     11492   Pave    Na       IR1
# 2           20          1          68.0      7922   Pave    Na       Reg
# 3           60          1          73.0      9802   Pave    Na       Reg
# 4           50          1          82.0     14235   Pave    Na       IR1
#
#   Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# 0          Lvl    AllPub    CulDSac        Gtl       Sawyer        RRAe
# 1          Lvl    AllPub    CulDSac        Gtl      SawyerW        Norm
# 2          Lvl    AllPub     Inside        Gtl        NAmes        Norm
# 3          Lvl    AllPub     Inside        Gtl       Timber        Norm
# 4          Lvl    AllPub     Inside        Gtl      SawyerW        Norm
#
#   Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  Year Built  \
# 0        Norm      1Fam      2Story             6             8        1976
# 1        Norm      1Fam      2Story             7             5        1996
# 2        Norm      1Fam      1Story             5             7        1953
# 3        Norm      1Fam      2Story             5             5        2006
# 4        Norm      1Fam      1.5Fin             6             8        1900
#
#    Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd Mas Vnr Type  \
# 0            2005      Gable   CompShg      HdBoard      Plywood      BrkFace
# 1            1997      Gable   CompShg      VinylSd      VinylSd      BrkFace
# 2            2007      Gable   CompShg      VinylSd      VinylSd          NaN
# 3            2007      Gable   CompShg      VinylSd      VinylSd          NaN
# 4            1993      Gable   CompShg      Wd Sdng      Plywood          NaN
#
#    Mas Vnr Area  Exter Qual Exter Cond Foundation  Bsmt Qual  Bsmt Cond  \
# 0         289.0           1         TA     CBlock          2          2
# 1         132.0           1         TA      PConc          3          2
# 2           0.0           2         Gd     CBlock          2          2
# 3           0.0           2         TA      PConc          3          2
# 4           0.0           2         TA      PConc          4          3
#
#    Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  \
# 0              2            GLQ         533.0            Unf           0.0
# 1              2            GLQ         637.0            Unf           0.0
# 2              2            GLQ         731.0            Unf           0.0
# 3              2            Unf           0.0            Unf           0.0
# 4              2            Unf           0.0            Unf           0.0
#
#    Bsmt Unf SF  Total Bsmt SF Heating  Heating QC Central Air Electrical  \
# 0        192.0          725.0    GasA           1           Y      SBrkr
# 1        276.0          913.0    GasA           1           Y      SBrkr
# 2        326.0         1057.0    GasA           2           Y      SBrkr
# 3        384.0          384.0    GasA           3           Y      SBrkr
# 4        676.0          676.0    GasA           2           Y      SBrkr
#
#    1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  \
# 0         725         754                0         1479             0.0
# 1         913        1209                0         2122             1.0
# 2        1057           0                0         1057             1.0
# 3         744         700                0         1444             0.0
# 4         831         614                0         1445             0.0
#
#    Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  Kitchen AbvGr  \
# 0             0.0          2          1              3              1
# 1             0.0          2          1              4              1
# 2             0.0          1          0              3              1
# 3             0.0          2          1              3              1
# 4             0.0          2          0              3              1
#
#   Kitchen Qual  TotRms AbvGrd Functional  Fireplaces Fireplace Qu Garage Type  \
# 0           Gd              6        Typ           0            0      Attchd
# 1           Gd              8        Typ           1           TA      Attchd
# 2           Gd              5        Typ           0            0      Detchd
# 3           TA              7        Typ           0            0     BuiltIn
# 4           TA              6        Typ           0            0      Detchd
#
#    Garage Yr Blt Garage Finish  Garage Cars  Garage Area  Garage Qual  \
# 0         1976.0           RFn          2.0        475.0            4
# 1         1997.0           RFn          2.0        559.0            4
# 2         1953.0           Unf          1.0        246.0            4
# 3         2007.0           Fin          2.0        400.0            4
# 4         1957.0           Unf          2.0        484.0            4
#
#    Garage Cond Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  \
# 0            4           Y             0             44               0
# 1            4           Y             0             74               0
# 2            4           Y             0             52               0
# 3            4           Y           100              0               0
# 4            4           N             0             59               0
#
#    3Ssn Porch  Screen Porch  Pool Area  Pool QC Fence Misc Feature  Misc Val  \
# 0           0             0          0        1    Na           Na         0
# 1           0             0          0        1    Na           Na         0
# 2           0             0          0        1    Na           Na         0
# 3           0             0          0        1    Na           Na         0
# 4           0             0          0        1    Na           Na         0
#
#    Mo Sold  Yr Sold Sale Type  SalePrice  Total_Sqft
# 0        3     2010       WD      130500      2248.0
# 1        4     2009       WD      220000      3109.0
# 2        1     2010       WD      109000      2166.0
# 3        4     2010       WD      174000      1928.0
# 4        3     2010       WD      138500      2180.0

# %%
train.corr(numeric_only = True)
# Out:
#                  MS SubClass  MS Zoning  Lot Frontage  Lot Area  Overall Qual  \
# MS SubClass         1.000000   0.271709     -0.407929 -0.245484      0.035763
# MS Zoning           0.271709   1.000000     -0.252965 -0.190837     -0.096255
# Lot Frontage       -0.407929  -0.252965      1.000000  0.394907      0.171598
# Lot Area           -0.245484  -0.190837      0.394907  1.000000      0.105824
# Overall Qual        0.035763  -0.096255      0.171598  0.105824      1.000000
# Overall Cond       -0.070141  -0.026240     -0.035651 -0.019185     -0.082770
# Year Built          0.035983  -0.151416      0.095087  0.036002      0.602964
# Year Remod/Add      0.044836  -0.045303      0.066754  0.050771      0.584654
# Mas Vnr Area       -0.002886  -0.088755      0.195996  0.167480      0.429777
# Exter Qual         -0.040306   0.047271      0.021751  0.015784     -0.361128
# Bsmt Qual           0.039534  -0.037565      0.119746  0.078601      0.598859
# Bsmt Cond          -0.011042   0.062927     -0.025346 -0.031099      0.004655
# Bsmt Exposure       0.054662  -0.123373      0.157384  0.195341      0.361400
# BsmtFin SF 1       -0.060425  -0.129872      0.198503  0.215648      0.279223
# BsmtFin SF 2       -0.068129  -0.089351      0.039632  0.041799     -0.027973
# Bsmt Unf SF        -0.139292  -0.012808      0.114505  0.041544      0.276437
# Total Bsmt SF      -0.224700  -0.178560      0.331276  0.277478      0.549407
# Heating QC          0.008136   0.037197     -0.078627 -0.027781     -0.400552
# 1st Flr SF         -0.246212  -0.206798      0.430305  0.381593      0.477136
# 2nd Flr SF          0.305771   0.087675      0.013116  0.029398      0.228152
# Low Qual Fin SF     0.031091   0.075320      0.004424  0.001273     -0.052338
# Gr Liv Area         0.068210  -0.081562      0.352488  0.327427      0.566701
# Bsmt Full Bath      0.025727  -0.084801      0.100637  0.113283      0.175896
# Bsmt Half Bath     -0.017030  -0.070945     -0.022416  0.029157     -0.047006
# Full Bath           0.142087  -0.038149      0.136841  0.125601      0.515080
# Half Bath           0.179404  -0.033953      0.036511  0.049995      0.274859
# Bedroom AbvGr      -0.003516  -0.112006      0.221965  0.139060      0.053373
# Screen Porch     0.013242  0.007122  0.029329 -0.017624   0.134581    0.090565
# Pool Area        0.904689  0.017661 -0.043118 -0.053768   0.023106    0.120277
# Pool QC          1.000000  0.008642 -0.033698 -0.044118   0.029275    0.136156
# Misc Val         0.008642  1.000000  0.019483  0.017269  -0.007375    0.149673
# Mo Sold         -0.033698  0.019483  1.000000 -0.147494   0.032735    0.035237
# Yr Sold         -0.044118  0.017269 -0.147494  1.000000  -0.015203   -0.013472
# SalePrice        0.029275 -0.007375  0.032735 -0.015203   1.000000    0.792196
# Total_Sqft       0.136156  0.149673  0.035237 -0.013472   0.792196    1.000000

# %%
#checking overall interaction between 'overall quality' and year Remod/Add

# %%
train['Year Remod/Add * Overall Qual'] = train['Year Remod/Add'] * train['Overall Qual']

# %%
print(train.columns)
# Out:
# Index(['MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area', 'Street',
#        'Alley', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config',
#        'Land Slope', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type',
#        'House Style', 'Overall Qual', 'Overall Cond', 'Year Built',
#        'Year Remod/Add', 'Roof Style', 'Roof Matl', 'Exterior 1st',
#        'Exterior 2nd', 'Mas Vnr Type', 'Mas Vnr Area', 'Exter Qual',
#        'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin Type 2', 'BsmtFin SF 2',
#        'Bsmt Unf SF', 'Total Bsmt SF', 'Heating', 'Heating QC', 'Central Air',
#        'Electrical', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF',
#        'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath',
#        'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual',
#        'TotRms AbvGrd', 'Functional', 'Fireplaces', 'Fireplace Qu',
#        'Garage Type', 'Garage Yr Blt', 'Garage Finish', 'Garage Cars',
#        'Garage Area', 'Garage Qual', 'Garage Cond', 'Paved Drive',
#        'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch',
#        'Screen Porch', 'Pool Area', 'Pool QC', 'Fence', 'Misc Feature',
#        'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type', 'SalePrice',
#        'Total_Sqft', 'Year Remod/Add * Overall Qual'],
#       dtype='object')

# %%
features = ['Total_Sqft','Lot Area','Year Remod/Add','Overall Qual','Bsmt Unf SF','Year Remod/Add * Overall Qual']
X = train[features] 
y = train['SalePrice']

# %%
X.corr()
# Out:
#                                Total_Sqft  Lot Area  Year Remod/Add  \
# Total_Sqft                       1.000000  0.360801        0.396580
# Lot Area                         0.360801  1.000000        0.050771
# Year Remod/Add                   0.396580  0.050771        1.000000
# Overall Qual                     0.666057  0.105824        0.584654
# Bsmt Unf SF                      0.348283  0.041544        0.160910
# Year Remod/Add * Overall Qual    0.666693  0.105641        0.610971
#
#                                Overall Qual  Bsmt Unf SF  \
# Total_Sqft                         0.666057     0.348283
# Lot Area                           0.105824     0.041544
# Year Remod/Add                     0.584654     0.160910
# Overall Qual                       1.000000     0.276437
# Bsmt Unf SF                        0.276437     1.000000
# Year Remod/Add * Overall Qual      0.999418     0.277148
#
#                                Year Remod/Add * Overall Qual
# Total_Sqft                                          0.666693
# Lot Area                                            0.105641
# Year Remod/Add                                      0.610971
# Overall Qual                                        0.999418
# Bsmt Unf SF                                         0.277148
# Year Remod/Add * Overall Qual                       1.000000

# %%
sns.heatmap(X.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <Axes: >

# %%
corr = X.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))  # Change np.bool to bool
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.4, cbar_kws={"shrink": .4})
# Out:
# <Axes: >

# %% [markdown]
# ## LinearRegression

# %%
plt.figure(figsize=(10,8))
sns.heatmap(train.corr(numeric_only = True)[['SalePrice']].sort_values(by='SalePrice', ascending=False), 
            annot=True,
           vmin=-1,
           vmax=1);

# %%
#Create the model

# %%
#set up X and y

# %%
X = train[['Overall Qual']]
y = train['SalePrice']

# %%
# Train Test Split - Let's see how our model performs on unseen data before making predictions on the test.csv (df_test)!

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
#initiate
lr = LinearRegression()

# %%
#Fit on Training data
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Evaluate on training and testing sets

#train score
lr.score(X_train, y_train)
# Out:
# 0.6333219308225758

# %%
#test Score
lr.score(X_test, y_test)
# Out:
# 0.6617682426512025

# %%
# Refit using all of the data in train.csv
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
#Make sale price predictions on homes that were in my test.csv

preds = lr.predict(test[['Overall Qual']])

preds.shape
# Out:
# (878,)

# %%
#Create SalePrice column in df_test

# %%
test['SalePrice'] = preds

# %%
test.head()
# Out:
#      Id  MS SubClass  MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  2658          190          2          69.0      9142   Pave  Grvl
# 1  2718           90          1          82.0      9662   Pave    Na
# 2  2414           60          1          58.0     17104   Pave    Na
# 3  1989           30          2          60.0      8520   Pave    Na
# 4   625           20          1          84.0      9500   Pave    Na
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        Norm        Norm    2fmCon      2Story             6             8
# 1        Norm        Norm    Duplex      1Story             5             4
# 2        Norm        Norm      1Fam      2Story             7             5
# 3        Norm        Norm      1Fam      1Story             5             6
# 4        Norm        Norm      1Fam      1Story             6             5
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1910            1950      Gable   CompShg      AsbShng      AsbShng
# 1        1977            1977      Gable   CompShg      Plywood      Plywood
# 2        2006            2006      Gable   CompShg      VinylSd      VinylSd
# 3        1923            2006      Gable   CompShg      Wd Sdng      Wd Sdng
# 4        1963            1963      Gable   CompShg      Plywood      Plywood
#
#   Mas Vnr Type  Mas Vnr Area  Exter Qual  Exter Cond Foundation  Bsmt Qual  \
# 0          NaN           0.0           3           2      Stone          5
# 1          NaN           0.0           3           3     CBlock          4
# 2          NaN           0.0           2           3      PConc          4
# 3          NaN           0.0           2           3     CBlock          3
# 4      BrkFace         247.0           3           3     CBlock          4
#
#    Bsmt Cond  Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0          2              2            Unf             0            Unf
# 1          2              2            Unf             0            Unf
# 2          3              4            GLQ           554            Unf
# 3          2              2            Unf             0            Unf
# 4          2              2            BLQ           609            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating  Heating QC Central Air  \
# 0             0         1020           1020    GasA           3           N
# 1             0         1967           1967    GasA           2           Y
# 2             0          100            654    GasA           1           Y
# 3             0          968            968    GasA           2           Y
# 4             0          785           1394    GasA           3           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      FuseP         908        1020                0         1928
# 1      SBrkr        1967           0                0         1967
# 2      SBrkr         664         832                0         1496
# 3      SBrkr         968           0                0          968
# 4      SBrkr        1394           0                0         1394
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0               0               0          2          0              4
# 1               0               0          2          0              6
# 2               1               0          2          1              3
# 3               0               0          1          0              2
# 4               1               0          1          1              3
#
#    Kitchen AbvGr  Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              2             2              9        Typ           0
# 1              2             3             10        Typ           0
# 2              1             4              7        Typ           1
# 3              1             3              5        Typ           0
# 4              1             3              6        Typ           2
#
#    Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0             1      Detchd         1910.0           Unf            1
# 1             1      Attchd         1977.0           Fin            2
# 2             5      Attchd         2006.0           RFn            2
# 3             1      Detchd         1935.0           Unf            2
# 4             5      Attchd         1963.0           RFn            2
#
#    Garage Area  Garage Qual  Garage Cond Paved Drive  Wood Deck SF  \
# 0        440.0            2            2           Y             0
# 1        580.0            4            4           Y           170
# 2        426.0            4            4           Y           100
# 3        480.0            3            4           N             0
# 4        514.0            4            4           Y             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area  \
# 0             60             112           0             0          0
# 1              0               0           0             0          0
# 2             24               0           0             0          0
# 3              0             184           0             0          0
# 4             76               0           0           185          0
#
#    Pool QC Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  \
# 0      0.0    Na           Na         0        4     2006       WD
# 1      0.0    Na           Na         0        8     2006       WD
# 2      0.0    Na           Na         0        9     2006       New
# 3      0.0    Na           Na         0        7     2007       WD
# 4      0.0    Na           Na         0        7     2009       WD
#
#        SalePrice
# 0  176483.047320
# 1  132015.099723
# 2  220950.994917
# 3  132015.099723
# 4  176483.047320

# %%
#Create DataFrame with only ID and SalePrice columns from df_test

# %%
lr_submission = test[['Id', 'SalePrice']]

# %%
#check before submitting
lr_submission.head()
# Out:
#      Id      SalePrice
# 0  2658  176483.047320
# 1  2718  132015.099723
# 2  2414  220950.994917
# 3  1989  132015.099723
# 4   625  176483.047320

# %%
#Set Index to Id
lr_submission.set_index('Id', inplace=True)

# %%
# Check 
lr_submission.head()
# Out:
#           SalePrice
# Id
# 2658  176483.047320
# 2718  132015.099723
# 2414  220950.994917
# 1989  132015.099723
# 625   176483.047320

# %%
lr_submission.to_csv('../Data_Submission/one_submission.csv')

# %% [markdown]
# ### Test another model

# %%
# Set up X and y

X = train[['Year Built']]
y = train['SalePrice']

# %%
#Train Test Split - Let's see how our model performs on unseen data before making predictions on the test.csv (df_test)!

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
# Instantiate
lr = LinearRegression()

# %%
# Fit on training data!
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Evaluate on training and testing sets

#train score
lr.score(X_train, y_train)
# Out:
# 0.31485104910486383

# %%
#test Score
lr.score(X_test, y_test)
# Out:
# 0.3637837013597105

# %%
# Refit using all of the data in train.csv
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
#Make sale price predictions on homes that were in my test.csv

preds = lr.predict(test[['Year Built']])

preds.shape
# Out:
# (878,)

# %%
test['SalePrice'] = preds

# %%
test.head()
# Out:
#      Id  MS SubClass  MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  2658          190          2          69.0      9142   Pave  Grvl
# 1  2718           90          1          82.0      9662   Pave    Na
# 2  2414           60          1          58.0     17104   Pave    Na
# 3  1989           30          2          60.0      8520   Pave    Na
# 4   625           20          1          84.0      9500   Pave    Na
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        Norm        Norm    2fmCon      2Story             6             8
# 1        Norm        Norm    Duplex      1Story             5             4
# 2        Norm        Norm      1Fam      2Story             7             5
# 3        Norm        Norm      1Fam      1Story             5             6
# 4        Norm        Norm      1Fam      1Story             6             5
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1910            1950      Gable   CompShg      AsbShng      AsbShng
# 1        1977            1977      Gable   CompShg      Plywood      Plywood
# 2        2006            2006      Gable   CompShg      VinylSd      VinylSd
# 3        1923            2006      Gable   CompShg      Wd Sdng      Wd Sdng
# 4        1963            1963      Gable   CompShg      Plywood      Plywood
#
#   Mas Vnr Type  Mas Vnr Area  Exter Qual  Exter Cond Foundation  Bsmt Qual  \
# 0          NaN           0.0           3           2      Stone          5
# 1          NaN           0.0           3           3     CBlock          4
# 2          NaN           0.0           2           3      PConc          4
# 3          NaN           0.0           2           3     CBlock          3
# 4      BrkFace         247.0           3           3     CBlock          4
#
#    Bsmt Cond  Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0          2              2            Unf             0            Unf
# 1          2              2            Unf             0            Unf
# 2          3              4            GLQ           554            Unf
# 3          2              2            Unf             0            Unf
# 4          2              2            BLQ           609            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating  Heating QC Central Air  \
# 0             0         1020           1020    GasA           3           N
# 1             0         1967           1967    GasA           2           Y
# 2             0          100            654    GasA           1           Y
# 3             0          968            968    GasA           2           Y
# 4             0          785           1394    GasA           3           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      FuseP         908        1020                0         1928
# 1      SBrkr        1967           0                0         1967
# 2      SBrkr         664         832                0         1496
# 3      SBrkr         968           0                0          968
# 4      SBrkr        1394           0                0         1394
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0               0               0          2          0              4
# 1               0               0          2          0              6
# 2               1               0          2          1              3
# 3               0               0          1          0              2
# 4               1               0          1          1              3
#
#    Kitchen AbvGr  Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              2             2              9        Typ           0
# 1              2             3             10        Typ           0
# 2              1             4              7        Typ           1
# 3              1             3              5        Typ           0
# 4              1             3              6        Typ           2
#
#    Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0             1      Detchd         1910.0           Unf            1
# 1             1      Attchd         1977.0           Fin            2
# 2             5      Attchd         2006.0           RFn            2
# 3             1      Detchd         1935.0           Unf            2
# 4             5      Attchd         1963.0           RFn            2
#
#    Garage Area  Garage Qual  Garage Cond Paved Drive  Wood Deck SF  \
# 0        440.0            2            2           Y             0
# 1        580.0            4            4           Y           170
# 2        426.0            4            4           Y           100
# 3        480.0            3            4           N             0
# 4        514.0            4            4           Y             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area  \
# 0             60             112           0             0          0
# 1              0               0           0             0          0
# 2             24               0           0             0          0
# 3              0             184           0             0          0
# 4             76               0           0           185          0
#
#    Pool QC Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  \
# 0      0.0    Na           Na         0        4     2006       WD
# 1      0.0    Na           Na         0        8     2006       WD
# 2      0.0    Na           Na         0        9     2006       New
# 3      0.0    Na           Na         0        7     2007       WD
# 4      0.0    Na           Na         0        7     2009       WD
#
#        SalePrice
# 0   88789.469173
# 1  189416.336796
# 2  232971.249647
# 3  108314.085279
# 4  168389.827143

# %%
#Create DataFrame with only ID and SalePrice columns from df_test

# %%
lr_submission = test[['Id', 'SalePrice']]

# %%
#check before submitting
lr_submission.head()
# Out:
#      Id      SalePrice
# 0  2658   88789.469173
# 1  2718  189416.336796
# 2  2414  232971.249647
# 3  1989  108314.085279
# 4   625  168389.827143

# %%
#Set Index to Id
lr_submission.set_index('Id', inplace=True)

# %%
#check before submitting
lr_submission.head()
# Out:
#           SalePrice
# Id
# 2658   88789.469173
# 2718  189416.336796
# 2414  232971.249647
# 1989  108314.085279
# 625   168389.827143

# %%
lr_submission.to_csv('../Data_Submission/yearbuilt_submission.csv')

# %% [markdown]
# ## Scaler

# %%
#again
features = ['Total_Sqft','Lot Area','Year Remod/Add','Overall Qual','Bsmt Unf SF','Year Remod/Add * Overall Qual', 'Year Built']
X = train[features] 
y = train['SalePrice']

# %%
X.corr()
# Out:
#                                Total_Sqft  Lot Area  Year Remod/Add  \
# Total_Sqft                       1.000000  0.360801        0.396580
# Lot Area                         0.360801  1.000000        0.050771
# Year Remod/Add                   0.396580  0.050771        1.000000
# Overall Qual                     0.666057  0.105824        0.584654
# Bsmt Unf SF                      0.348283  0.041544        0.160910
# Year Remod/Add * Overall Qual    0.666693  0.105641        0.610971
# Year Built                       0.413040  0.036002        0.629116
#
#                                Overall Qual  Bsmt Unf SF  \
# Total_Sqft                         0.666057     0.348283
# Lot Area                           0.105824     0.041544
# Year Remod/Add                     0.584654     0.160910
# Overall Qual                       1.000000     0.276437
# Bsmt Unf SF                        0.276437     1.000000
# Year Remod/Add * Overall Qual      0.999418     0.277148
# Year Built                         0.602964     0.137114
#
#                                Year Remod/Add * Overall Qual  Year Built
# Total_Sqft                                          0.666693    0.413040
# Lot Area                                            0.105641    0.036002
# Year Remod/Add                                      0.610971    0.629116
# Overall Qual                                        0.999418    0.602964
# Bsmt Unf SF                                         0.277148    0.137114
# Year Remod/Add * Overall Qual                       1.000000    0.615038
# Year Built                                          0.615038    1.000000

# %%
ss= StandardScaler()
ss.fit(X)
# Out:
# StandardScaler()

# %%
print(ss.mean_)
# Out:
# [2.69267967e+03 1.00652082e+04 1.98419015e+03 6.11214042e+00
#  5.67451487e+02 1.21451819e+04 1.97170892e+03]

# %%
ss = StandardScaler()
ss.fit(X)
print('means', ss.mean_)
print('stds', ss.scale_)
X_scaled = ss.transform(X)
X_scaled[:6]
# Out:
# means [2.69267967e+03 1.00652082e+04 1.98419015e+03 6.11214042e+00
#  5.67451487e+02 1.21451819e+04 1.97170892e+03]
# stds [8.81274512e+02 6.74084500e+03 2.10311213e+01 1.42592280e+00
#  4.44914344e+02 2.90781366e+03 3.01705313e+01]
# array([[-0.50458701,  0.51207108,  0.98947881, -0.0786441 , -0.84387364,
#         -0.03961116,  0.14222744],
#        [ 0.47240709,  0.21166364,  0.60909015,  0.62265614, -0.65507325,
#          0.63065187,  0.80512594],
#        [-0.59763406, -0.31794355,  1.08457597, -0.77994434, -0.54269207,
#         -0.72569363, -0.62010583],
#        [-0.86769747, -0.03904677,  1.08457597, -0.77994434, -0.4123299 ,
#         -0.72569363,  1.1365752 ],
#        [-0.58174798,  0.61858592,  0.41889582, -0.0786441 ,  0.2439762 ,
#         -0.06437203, -2.37678686],
#        [ 0.80828428,  0.95341041,  0.84683306, -0.0786441 , -0.02349101,
#         -0.04580137, -0.18922181]])

# %%
#Generate Regression Model and model validation

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train.head()
# Out:
#       Total_Sqft  Lot Area  Year Remod/Add  Overall Qual  Bsmt Unf SF  \
# 532       3218.0     10667            1971             6        749.0
# 415       3793.0     12888            1980             7        717.0
# 273       1922.0      7200            2002             5        317.0
# 1460      3906.0     14000            1997             7        105.0
# 250       4022.0     11929            1995             8       1242.0
#
#       Year Remod/Add * Overall Qual  Year Built
# 532                           11826        1971
# 415                           13860        1937
# 273                           10010        1950
# 1460                          13979        1996
# 250                           15960        1995

# %%
train.shape
# Out:
# (2051, 81)

# %%
X_train.shape
# Out:
# (1538, 7)

# %%
y_train.shape
# Out:
# (1538,)

# %%
X_test.shape
# Out:
# (513, 7)

# %%
y_test.shape
# Out:
# (513,)

# %%
y_train.head()
# Out:
# 532     167300
# 415     219000
# 273     129000
# 1460    328000
# 250     290000
# Name: SalePrice, dtype: int64

# %%
sns.pairplot(X_train)
# Out:
# /Users/rajashreechoudhary/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#there are quite a fe features to show correlation to SalePrice, such as Total_Sqft, Year Remod/Add,
#overall qual, bsmt Unf SF, lot area, year built

# %%
#Starting with year built

# %%
X_train.fillna(X_train.mean(), inplace=True)

# %%
y_train.fillna(y_train.mean(), inplace=True)

# %%
y_test.fillna(y_test.mean(), inplace=True)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
##Model evaluation & Baseline score

# %%
lr.score(X_test,y_test)
# Out:
# 0.8575785754901016

# %%
lr.score(X_train, y_train)
# Out:
# 0.7991691070491058

# %% [markdown]
# Model is slightly overfit as the test score is .85 and the train score is .79.

# %%
lr.coef_
# Out:
# array([ 3.47828066e+01,  1.38340172e+00, -2.09470346e+03, -8.63461071e+05,
#        -2.11710939e+01,  4.46840817e+02,  1.43733799e+02])

# %%
cross_val_score(lr, X_train, y_train, cv=5).mean()
# Out:
# 0.7733952669241017

# %% [markdown]
# Cross value score of training set is .77

# %%
def adjusted_r2(n, p, y, y_preds):
    return 1 - (1 - r2_score(y, y_preds)) * ((n-1) / (n - p - 1))

# %%
def scores(model, X, y):
    print(f'r2 score: {r2_score(y, lr.predict(X))}')
    print(f'RMSE: {np.sqrt(mean_squared_error(y, lr.predict(X)))}')

# %%
train_preds = lr.predict(X_test)
train_preds[:10]
r2_score(y_test, train_preds)
# Out:
# 0.8575785754901016

# %%
print('Training Scores:')
scores(lr, X_train, y_train)
print(f'adjusted r2 score: {adjusted_r2(X_train.shape[0], X_train.shape[1], y_train, lr.predict(X_train))}')
# Out:
# Training Scores:
# r2 score: 0.7991691070491058
# RMSE: 35639.290742419165
# adjusted r2 score: 0.79825027289835

# %%
preds = lr.predict(X_test)

# %%
residuals = y_test - preds

# %%
plt.hist(residuals)
# Out:
# (array([  1.,   1.,   7.,  30., 154., 232.,  55.,  23.,   4.,   6.]),
#  array([-141525.30521431, -114788.69235233,  -88052.07949036,
#          -61315.46662838,  -34578.8537664 ,   -7842.24090442,
#           18894.37195755,   45630.98481953,   72367.59768151,
#           99104.21054349,  125840.82340547]),
#  <BarContainer object of 10 artists>)

# %%
np.log(y_test).hist();

# %%
np.exp(np.log(y_test)).hist();

# %%
actual_values = y_test
plt.scatter(preds, actual_values, alpha=.7,
            color='b') 
plt.xlabel('Predicted Price')
plt.ylabel('Actual Price')
plt.title('Linear Regression Model')
plt.show()

# %% [markdown]
# From the above graph we can see that how predicted price and the actual price is correlated.

# %%
#hypothesis testing

# %%
features = ['Total_Sqft','Lot Area','Year Remod/Add','Overall Qual','Bsmt Unf SF','Year Remod/Add * Overall Qual', 'Year Built']
X = train[features] 
X = sm.add_constant(X)

# %%
X.fillna(X.mean(), inplace=True)

# %%
model=sm.OLS(y,X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.815
# Model:                            OLS   Adj. R-squared:                  0.814
# Method:                 Least Squares   F-statistic:                     1285.
# Date:                Fri, 16 Feb 2024   Prob (F-statistic):               0.00
# Time:                        05:12:14   Log-Likelihood:                -24316.
# No. Observations:                2051   AIC:                         4.865e+04
# Df Residuals:                    2043   BIC:                         4.869e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          3.814e+06   3.41e+05     11.174      0.000    3.14e+06    4.48e+06
# Total_Sqft                       39.0549      1.290     30.264      0.000      36.524      41.586
# Lot Area                          1.0067      0.123      8.191      0.000       0.766       1.248
# Year Remod/Add                -2102.9146    166.600    -12.623      0.000   -2429.638   -1776.191
# Overall Qual                  -8.538e+05   5.79e+04    -14.737      0.000   -9.67e+05    -7.4e+05
# Bsmt Unf SF                     -22.2822      1.829    -12.183      0.000     -25.869     -18.695
# Year Remod/Add * Overall Qual   441.5303     29.168     15.138      0.000     384.329     498.732
# Year Built                      149.1100     35.385      4.214      0.000      79.716     218.504
# ==============================================================================
# Omnibus:                     1700.159   Durbin-Watson:                   2.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           398345.640
# Skew:                          -3.016   Prob(JB):                         0.00
# Kurtosis:                      71.007   Cond. No.                     7.82e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.82e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#test the set

# %%
test.head()
# Out:
#      Id  MS SubClass  MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  2658          190          2          69.0      9142   Pave  Grvl
# 1  2718           90          1          82.0      9662   Pave    Na
# 2  2414           60          1          58.0     17104   Pave    Na
# 3  1989           30          2          60.0      8520   Pave    Na
# 4   625           20          1          84.0      9500   Pave    Na
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        Norm        Norm    2fmCon      2Story             6             8
# 1        Norm        Norm    Duplex      1Story             5             4
# 2        Norm        Norm      1Fam      2Story             7             5
# 3        Norm        Norm      1Fam      1Story             5             6
# 4        Norm        Norm      1Fam      1Story             6             5
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1910            1950      Gable   CompShg      AsbShng      AsbShng
# 1        1977            1977      Gable   CompShg      Plywood      Plywood
# 2        2006            2006      Gable   CompShg      VinylSd      VinylSd
# 3        1923            2006      Gable   CompShg      Wd Sdng      Wd Sdng
# 4        1963            1963      Gable   CompShg      Plywood      Plywood
#
#   Mas Vnr Type  Mas Vnr Area  Exter Qual  Exter Cond Foundation  Bsmt Qual  \
# 0          NaN           0.0           3           2      Stone          5
# 1          NaN           0.0           3           3     CBlock          4
# 2          NaN           0.0           2           3      PConc          4
# 3          NaN           0.0           2           3     CBlock          3
# 4      BrkFace         247.0           3           3     CBlock          4
#
#    Bsmt Cond  Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0          2              2            Unf             0            Unf
# 1          2              2            Unf             0            Unf
# 2          3              4            GLQ           554            Unf
# 3          2              2            Unf             0            Unf
# 4          2              2            BLQ           609            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating  Heating QC Central Air  \
# 0             0         1020           1020    GasA           3           N
# 1             0         1967           1967    GasA           2           Y
# 2             0          100            654    GasA           1           Y
# 3             0          968            968    GasA           2           Y
# 4             0          785           1394    GasA           3           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      FuseP         908        1020                0         1928
# 1      SBrkr        1967           0                0         1967
# 2      SBrkr         664         832                0         1496
# 3      SBrkr         968           0                0          968
# 4      SBrkr        1394           0                0         1394
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0               0               0          2          0              4
# 1               0               0          2          0              6
# 2               1               0          2          1              3
# 3               0               0          1          0              2
# 4               1               0          1          1              3
#
#    Kitchen AbvGr  Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              2             2              9        Typ           0
# 1              2             3             10        Typ           0
# 2              1             4              7        Typ           1
# 3              1             3              5        Typ           0
# 4              1             3              6        Typ           2
#
#    Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0             1      Detchd         1910.0           Unf            1
# 1             1      Attchd         1977.0           Fin            2
# 2             5      Attchd         2006.0           RFn            2
# 3             1      Detchd         1935.0           Unf            2
# 4             5      Attchd         1963.0           RFn            2
#
#    Garage Area  Garage Qual  Garage Cond Paved Drive  Wood Deck SF  \
# 0        440.0            2            2           Y             0
# 1        580.0            4            4           Y           170
# 2        426.0            4            4           Y           100
# 3        480.0            3            4           N             0
# 4        514.0            4            4           Y             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area  \
# 0             60             112           0             0          0
# 1              0               0           0             0          0
# 2             24               0           0             0          0
# 3              0             184           0             0          0
# 4             76               0           0           185          0
#
#    Pool QC Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  \
# 0      0.0    Na           Na         0        4     2006       WD
# 1      0.0    Na           Na         0        8     2006       WD
# 2      0.0    Na           Na         0        9     2006       New
# 3      0.0    Na           Na         0        7     2007       WD
# 4      0.0    Na           Na         0        7     2009       WD
#
#        SalePrice
# 0   88789.469173
# 1  189416.336796
# 2  232971.249647
# 3  108314.085279
# 4  168389.827143

# %%
test.shape
# Out:
# (878, 80)

# %%
train.shape
# Out:
# (2051, 81)

# %%
test['Year Remod/Add * Overall Qual'] = test['Year Remod/Add'] * test['Overall Qual']

# %%
test['Total_Sqft']= test['Total Bsmt SF']+test['Wood Deck SF']+test['Open Porch SF']+test['1st Flr SF']+test['2nd Flr SF']

# %%
#Answer

# %%
X_test.shape
# Out:
# (513, 7)

# %%
X_test = test[['Total_Sqft','Lot Area','Year Remod/Add','Overall Qual','Bsmt Unf SF','Year Remod/Add * Overall Qual', 'Year Built']]
y_hat = lr.predict(X_test)

# %%
X_test.shape
# Out:
# (878, 7)

# %%
my_submission2 = pd.DataFrame({'Id': test['Id'],'SalePrice': y_hat,})
my_submission2.head()
# Out:
#      Id      SalePrice
# 0  2658  142114.695577
# 1  2718  166425.152960
# 2  2414  226611.340472
# 3  1989  106869.999303
# 4   625  157816.766383

# %%
my_submission2.to_csv('../Data_Submission/submission_ss.csv',index=False)
